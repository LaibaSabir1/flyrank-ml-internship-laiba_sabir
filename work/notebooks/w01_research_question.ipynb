# %% [markdown]
# <a href="https://colab.research.google.com/github/LaibaSabir1/flyrank-ml-internship-laiba_sabir/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LaibaSabir1/flyrank-ml-internship-laiba_sabir/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/LaibaSabir1/flyrank-ml-internship-laiba_sabir"
REPO_DIR = "flyrank-ml-internship-laiba_sabir"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-laiba_sabir
# Starter data found. You're ready.

# %%
from IPython.display import Markdown, display

display(Markdown("""
**My lane:** Content Refresh / Page Review Priority

**Why:** I'm sticking with the content-refresh lane rather than freestyling, because the
starter pipeline is already built around this dataset and I've seen it run end-to-end in
notebooks 01 and 02 — the baseline rule scoring ~24% precision versus the learned model
scoring ~74% on Precision@50. Staying in this lane lets me build directly on code and
intuition I already have, rather than starting from zero on an unfamiliar slice of data.
It's also a genuinely useful business problem: with a fixed reviewer capacity, knowing
which of ~30k pages to look at first has real decision-support value.
"""))
# Out:
# **My lane:** Content Refresh / Page Review Priority
#
# **Why:** I'm sticking with the content-refresh lane rather than freestyling, because the
# starter pipeline is already built around this dataset and I've seen it run end-to-end in
# notebooks 01 and 02 — the baseline rule scoring ~24% precision versus the learned model
# scoring ~74% on Precision@50. Staying in this lane lets me build directly on code and
# intuition I already have, rather than starting from zero on an unfamiliar slice of data.
# It's also a genuinely useful business problem: with a fixed reviewer capacity, knowing
# which of ~30k pages to look at first has real decision-support value.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
**The decision:** Out of roughly 30,000 content pages, which ones should a content
reviewer look at first when they only have time to check a limited number per week?

**Who acts, and how:** A content editor/reviewer takes the ranked list this project
produces and manually inspects the top-ranked pages, deciding whether to refresh,
expand, or simply monitor each one.

**Cost of a wrong call:** If the ranking is wrong, there are two possible costs —
either the reviewer wastes limited time on pages that didn't actually need attention
(a false positive), or a page that is genuinely declining gets missed and continues
losing traffic unnoticed (a false negative). Since reviewer time is the scarce
resource, both errors are costly in different ways.
"""))
# Out:
# **The decision:** Out of roughly 30,000 content pages, which ones should a content
# reviewer look at first when they only have time to check a limited number per week?
#
# **Who acts, and how:** A content editor/reviewer takes the ranked list this project
# produces and manually inspects the top-ranked pages, deciding whether to refresh,
# expand, or simply monitor each one.
#
# **Cost of a wrong call:** If the ranking is wrong, there are two possible costs —
# either the reviewer wastes limited time on pages that didn't actually need attention
# (a false positive), or a page that is genuinely declining gets missed and continues
# losing traffic unnoticed (a false negative). Since reviewer time is the scarce
# resource, both errors are costly in different ways.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

total_pages = len(df)
declining_rate = (df["trend_direction"].str.lower() == "down").mean()
median_impressions = df["impressions_90d"].median()

print("Total pages:", total_pages)
print("Declining rate (trend_direction == 'down'):", round(declining_rate, 3))
print("Median impressions (90d):", median_impressions)
display(Markdown(f"""
**What this shows:** Over half of all pages in this dataset ({declining_rate:.1%}) are currently labeled as declining, so prioritizing which ones to review first genuinely matters — this isn't a rare-event problem. On top of that, the starter pipeline shows a
simple hand-written rule only gets **24%** of its top-50 picks right (Precision@50),while a trained model gets **~74%** — roughly a 3x improvement. That gap is strong
evidence that a learned ranking can meaningfully beat a fixed rule on this data,which is exactly why this lane is worth pursuing.
"""))
# Out:
# Total pages: 30000
# Declining rate (trend_direction == 'down'): 0.542
# Median impressions (90d): 731.0
# **What this shows:** Over half of all pages in this dataset (54.2%) are currently labeled as declining, so prioritizing which ones to review first genuinely matters — this isn't a rare-event problem. On top of that, the starter pipeline shows a
# simple hand-written rule only gets **24%** of its top-50 picks right (Precision@50),while a trained model gets **~74%** — roughly a 3x improvement. That gap is strong
# evidence that a learned ranking can meaningfully beat a fixed rule on this data,which is exactly why this lane is worth pursuing.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
display(Markdown("""
**What I can claim:** My results are *observed* and *decision-support* only. For example: "these pages showed a decline in the last 90 days," or "this ranked list is a
reasonable starting point for reviewers with limited time."

**What I cannot claim:** I cannot say my model "predicts Google's algorithm," "proves" why a page is declining, or that refreshing a page will *cause* it to recover. Proving causation would require a real experiment (e.g. an A/B test on refreshed vs. non-refreshed pages), which this dataset does not provide. My work stays in the observed / directional / decision-support territory, not the causal-proof territory.
"""))
# Out:
# **What I can claim:** My results are *observed* and *decision-support* only. For example: "these pages showed a decline in the last 90 days," or "this ranked list is a
# reasonable starting point for reviewers with limited time."
#
# **What I cannot claim:** I cannot say my model "predicts Google's algorithm," "proves" why a page is declining, or that refreshing a page will *cause* it to recover. Proving causation would require a real experiment (e.g. an A/B test on refreshed vs. non-refreshed pages), which this dataset does not provide. My work stays in the observed / directional / decision-support territory, not the causal-proof territory.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
